# %%
# !pip install medmnist
# Out:
# Requirement already satisfied: medmnist in c:\users\pc\anaconda3\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy in c:\users\pc\anaconda3\lib\site-packages (from medmnist) (1.24.4)
# Requirement already satisfied: pandas in c:\users\pc\anaconda3\lib\site-packages (from medmnist) (1.5.3)
# Requirement already satisfied: scikit-learn in c:\users\pc\anaconda3\lib\site-packages (from medmnist) (1.3.0)
# Requirement already satisfied: scikit-image in c:\users\pc\anaconda3\lib\site-packages (from medmnist) (0.20.0)
# Requirement already satisfied: tqdm in c:\users\pc\anaconda3\lib\site-packages (from medmnist) (4.67.1)
# Requirement already satisfied: Pillow in c:\users\pc\anaconda3\lib\site-packages (from medmnist) (11.1.0)
# Requirement already satisfied: fire in c:\users\pc\anaconda3\lib\site-packages (from medmnist) (0.7.1)
# Requirement already satisfied: torch in c:\users\pc\anaconda3\lib\site-packages (from medmnist) (2.7.0)
# Requirement already satisfied: torchvision in c:\users\pc\anaconda3\lib\site-packages (from medmnist) (0.22.0)
# Requirement already satisfied: termcolor in c:\users\pc\anaconda3\lib\site-packages (from fire->medmnist) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\pc\anaconda3\lib\site-packages (from pandas->medmnist) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pc\anaconda3\lib\site-packages (from pandas->medmnist) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\pc\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->medmnist) (1.16.0)
# Requirement already satisfied: scipy>=1.8 in c:\users\pc\anaconda3\lib\site-packages (from scikit-image->medmnist) (1.15.2)
# Requirement already satisfied: networkx>=2.8 in c:\users\pc\anaconda3\lib\site-packages (from scikit-image->medmnist) (2.8.8)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\pc\anaconda3\lib\site-packages (from scikit-image->medmnist) (2.26.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\pc\anaconda3\lib\site-packages (from scikit-image->medmnist) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\pc\anaconda3\lib\site-packages (from scikit-image->medmnist) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\pc\anaconda3\lib\site-packages (from scikit-image->medmnist) (25.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\pc\anaconda3\lib\site-packages (from scikit-image->medmnist) (0.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\pc\anaconda3\lib\site-packages (from scikit-learn->medmnist) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\pc\anaconda3\lib\site-packages (from scikit-learn->medmnist) (2.2.0)
# Requirement already satisfied: filelock in c:\users\pc\anaconda3\lib\site-packages (from torch->medmnist) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\pc\anaconda3\lib\site-packages (from torch->medmnist) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\pc\anaconda3\lib\site-packages (from torch->medmnist) (1.14.0)
# Requirement already satisfied: jinja2 in c:\users\pc\anaconda3\lib\site-packages (from torch->medmnist) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\pc\anaconda3\lib\site-packages (from torch->medmnist) (2025.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\pc\anaconda3\lib\site-packages (from sympy>=1.13.3->torch->medmnist) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pc\anaconda3\lib\site-packages (from jinja2->torch->medmnist) (2.1.1)
# Requirement already satisfied: colorama in c:\users\pc\anaconda3\lib\site-packages (from tqdm->medmnist) (0.4.6)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tqdm import tqdm
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torchvision.transforms as transforms
from sklearn.metrics import confusion_matrix, f1_score
import medmnist
from medmnist import INFO, Evaluator
import matplotlib.pyplot as plt
from MLNN import MLNN
from fit import fit
from fit import evaluate_nn
from CNN import CNN

# %%
print(f"MedMNIST v{medmnist.__version__} @ {medmnist.HOMEPAGE}")
# Out:
# MedMNIST v3.0.2 @ https://github.com/MedMNIST/MedMNIST/

# %% [markdown]
# # We work on the 2D dataset with size 28x28

# %%
data_flag = 'bloodmnist'
download = True
BATCH_SIZE = 128

info = INFO[data_flag]
task = info['task']
n_channels = info['n_channels']
n_classes = len(info['label'])

DataClass = getattr(medmnist, info['python_class'])

# %% [markdown]
# ## First, we read the MedMNIST data, preprocess them and encapsulate them into dataloader form.

# %%
# preprocessing
data_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5,0.5,0.5], std=[0.5,0.5,0.5]),
])

# load the data
train_dataset = DataClass(split='train', transform=data_transform, download=download)
test_dataset = DataClass(split='test', transform=data_transform, download=download)
pil_dataset = DataClass(split='train', download=download)

# encapsulate data into dataloader form
train_loader = data.DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True)
train_loader_at_eval = data.DataLoader(dataset=train_dataset, batch_size=2*BATCH_SIZE, shuffle=False)
test_loader = data.DataLoader(dataset=test_dataset, batch_size=2*BATCH_SIZE, shuffle=False)

# %%
print(train_dataset)
print("===================")
print(test_dataset)
# Out:
# Dataset BloodMNIST of size 28 (bloodmnist)
#     Number of datapoints: 11959
#     Root location: C:\Users\PC\.medmnist
#     Split: train
#     Task: multi-class
#     Number of channels: 3
#     Meaning of labels: {'0': 'basophil', '1': 'eosinophil', '2': 'erythroblast', '3': 'immature granulocytes(myelocytes, metamyelocytes and promyelocytes)', '4': 'lymphocyte', '5': 'monocyte', '6': 'neutrophil', '7': 'platelet'}
#     Number of samples: {'train': 11959, 'val': 1712, 'test': 3421}
#     Description: The BloodMNIST is based on a dataset of individual normal cells, captured from individuals without infection, hematologic or oncologic disease and free of any pharmacologic treatment at the moment of blood collection. It contains a total of 17,092 images and is organized into 8 classes. We split the source dataset with a ratio of 7:1:2 into training, validation and test set. The source images with resolution 3×360×363 pixels are center-cropped into 3×200×200, and then resized into 3×28×28.
#     License: CC BY 4.0
# ===================
# Dataset BloodMNIST of size 28 (bloodmnist)
#     Number of datapoints: 3421
#     Root location: C:\Users\PC\.medmnist
#     Split: test
#     Task: multi-class
#     Number of channels: 3
#     Meaning of labels: {'0': 'basophil', '1': 'eosinophil', '2': 'erythroblast', '3': 'immature granulocytes(myelocytes, metamyelocytes and promyelocytes)', '4': 'lymphocyte', '5': 'monocyte', '6': 'neutrophil', '7': 'platelet'}
#     Number of samples: {'train': 11959, 'val': 1712, 'test': 3421}
#     Description: The BloodMNIST is based on a dataset of individual normal cells, captured from individuals without infection, hematologic or oncologic disease and free of any pharmacologic treatment at the moment of blood collection. It contains a total of 17,092 images and is organized into 8 classes. We split the source dataset with a ratio of 7:1:2 into training, validation and test set. The source images with resolution 3×360×363 pixels are center-cropped into 3×200×200, and then resized into 3×28×28.
#     License: CC BY 4.0

# %%
# visualization

train_dataset.montage(length=2)
# Out:
# <PIL.Image.Image image mode=RGB size=56x56>

# %%
train_dataset.montage(length=8)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
#Access a single image / label
image, label = train_dataset[2]  # image is a tensor , label is an  int
print("Shape da imagem:", image.shape)
print("Classe:", label)

# Convert to NumPy array
image_array = image.numpy()
print("Size:", image_array.shape )

#Access a subset of images
img = train_dataset[1][0].numpy   # image
lab = train_dataset[1][1]   # label
start_idx = 10
end_idx = 20  # exclusive
images_array = np.stack([train_dataset[i][0].numpy() for i in range(start_idx, end_idx)])
labels_array = np.array([train_dataset[i][1] for i in range(start_idx, end_idx)])

print("Size:", images_array.shape )
print(labels_array)
# Out:
# Shape da imagem: torch.Size([3, 28, 28])
# Classe: [6]
# Size: (3, 28, 28)
# Size: (10, 3, 28, 28)
# [[1]
#  [1]
#  [6]
#  [7]
#  [6]
#  [3]
#  [7]
#  [2]
#  [6]
#  [1]]

# %%
def plot_graph(acc_train, title,n_epochs):
    epochs = range(1, n_epochs + 1)

    plt.figure(figsize=(8,5))
    plt.plot(epochs, acc_train, label='Train Accuracy', marker='o', color='blue')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title(title)
    plt.grid(True)
    plt.legend()
    plt.show()

def plot_class_metrics(per_class_precision, per_class_f1, title='Precision and F1 Score per Class'):
    num_classes = len(per_class_precision)
    
    class_names = [f'Class {i}' for i in range(num_classes)]
    
    x = np.arange(num_classes)
    width = 0.35 

    plt.figure(figsize=(12,6))
    
    # Barras lado a lado
    plt.bar(x - width/2, per_class_precision*100, width, label='Precision', color='skyblue')
    plt.bar(x + width/2, per_class_f1*100, width, label='F1 Score', color='salmon')
    
    plt.xlabel('Classes')
    plt.ylabel('Percentage (%)')
    plt.title(title)
    plt.xticks(x, class_names)
    plt.ylim(0, 100)
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

def plot_losses(losses, title='Loss over Epochs'):
    epochs = range(1, len(losses) + 1)
    plt.figure(figsize=(8,5))
    plt.plot(epochs, losses, label='Training Loss', marker='o', color='red')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(title)
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
num_inputs = 28 * 28 * 3
num_classes = 8
hidden_layer_sizes = ((num_inputs+num_classes)//2,) * 2 # 2 hidden layer
n_epochs = 200

models = ["MLNN","CNN"]

losses = {
    "CrossEntropy": nn.CrossEntropyLoss(),
    "NLL": nn.NLLLoss() 
}

optimizers = {
    "SGD": lambda params: optim.SGD(params, lr=0.01, momentum=0.9),
    "Adam": lambda params: optim.Adam(params, lr=0.001)
}

with open("results.txt", "w") as f:
    for model_name in models:
        for loss_name, criterion in losses.items():
            for opt_name, opt_fn in optimizers.items():
                if model_name == "MLNN":
                    model = MLNN(input_size=num_inputs, hidden_sizes=hidden_layer_sizes, num_classes=num_classes)
                    flatten = True
                else:
                    model = CNN(input_channels=3, num_classes=num_classes)
                    flatten = False
                    
                use_nll = (loss_name=="NLL")
                optimizer = opt_fn(model.parameters())
                
                print(f"Training Model: {model_name}, Loss: {loss_name}, Optimizer: {opt_name}")
                
                trained_model, losses_values, acc_train = fit(train_loader, model, criterion, optimizer, n_epochs=n_epochs, to_device=True, flatten=flatten, use_nll=use_nll)
                
                f.write(f"Modelo: {model_name}, Loss: {loss_name}, Optimizer: {opt_name}\n")
                f.write("Resultados:\n")
                acc_evaluate, cm, f1_global, per_class_acc, per_class_precision, per_class_f1 = evaluate_nn(trained_model, test_loader, flatten=flatten, file=f)
                f.write("\n" + "-"*50 + "\n")
                plot_losses(losses_values, title=f"Loss over Epochs - Model: {model_name}, Loss: {loss_name}, Optimizer: {opt_name}")
                plot_class_metrics(per_class_precision, per_class_f1, title=f"Class Metrics - Model: {model_name}, Loss: {loss_name}, Optimizer: {opt_name}")
# Out:
# Training Model: MLNN, Loss: CrossEntropy, Optimizer: SGD
# Early stopping at epoch 116
# Training Model: MLNN, Loss: CrossEntropy, Optimizer: Adam
# Early stopping at epoch 84
# Training Model: MLNN, Loss: NLL, Optimizer: SGD
# Early stopping at epoch 125
# Training Model: MLNN, Loss: NLL, Optimizer: Adam
# Early stopping at epoch 115
# Training Model: CNN, Loss: CrossEntropy, Optimizer: SGD
# Early stopping at epoch 81
# Training Model: CNN, Loss: CrossEntropy, Optimizer: Adam
# Early stopping at epoch 65
# Training Model: CNN, Loss: NLL, Optimizer: SGD
# Early stopping at epoch 86
# Training Model: CNN, Loss: NLL, Optimizer: Adam
# Early stopping at epoch 62
